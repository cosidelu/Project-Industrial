# %%
import kinematics_v2 as kin
from robot_control import RobotController
import numpy as np
import Variables as vb

#vb.HELMET_CENTER_CORNER

IP_LAB = "192.168.1.3"
controller = RobotController(ip_address=IP_LAB,
                             default_position_j=vb.LOOK_DOWN_POSITION_J_INIZIO)
controller.disconnect()
controller.connect()
# Out:
# [15:21:50] INFO     Succesfully connected to robot Ethernet Slave and Modbus.                         techman.py:25
# [15:21:51] INFO     Connected to Listen Node                                                          techman.py:37

# %%
controller.default_positioning()

# %%
controller.robot.tcp_coord
# Out:
# [33.99742889404297,
#  439.9992980957031,
#  700.0045166015625,
#  180.0,
#  0.0003778678656090051,
#  -90.0]

# %%
controller.robot.joints
# Out:
# [-115.16104125976562,
#  22.920495986938477,
#  -106.5320816040039,
#  -6.388057708740234,
#  -89.99986267089844,
#  244.8389129638672]

# %%
#apertura visiera
controller.move_ptp(vb.VISIERA_0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 #apertura visiera
# ----> 2 controller.move_ptp(vb.VISIERA_0)
#
# File c:\Users\cosid\Desktop\Industrial Robotics\Project\robot_control.py:63, in RobotController.move_ptp(self, pose, speed, data_format)
#      61 """Esegue un movimento PTP (Punto-Punto) e attende il completamento"""
#      62 self.robot.ptp(pose, speed, data_format=data_format)
# ---> 63 self._wait_until_pose(pose, use_joints=False)
#
# File c:\Users\cosid\Desktop\Industrial Robotics\Project\robot_control.py:58, in RobotController._wait_until_pose(self, target_pose, use_joints)
#      56 if time.time() - start > self.default_timeout:
#      57     raise TimeoutError(f"Target non raggiunto. Errore: {np.round(errors, 2)}")
# ---> 58 time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
controller.move_ptp(vb.VISIERA_1)
controller.move_line(vb.VISIERA_2)
controller.move_circle(vb.VISIERA_3,vb.VISIERA_4)
controller.move_line(vb.VISIERA_5)

# %%
#spostamento per la seconda azione
controller.move_ptp(vb.ALLONTANAMENTO)
controller.move_joints(vb.ALLONTANAMENTO_JOINT)

# %%
#chiusura visiera da sole
controller.move_ptp(vb.SOLE_1)
controller.move_line(vb.SOLE_2)

# %%
controller.move_line(vb.SOLE_3)
controller.move_line(vb.SOLE_4)

# %%
#pressione pulsante
controller.move_ptp(vb.LUNA_1)
controller.move_line(vb.LUNA_2)
controller.move_line(vb.LUNA_3)
controller.move_line(vb.LUNA_2)

# %%
#più ci allontaniamo e ci prepariamo per la task dopo
controller.move_ptp(vb.LUNA_5)
controller.move_ptp(vb.LUNA_6)

# %%
#chiudiamo la visiera
controller.move_joints(vb.VISIERA_10_J)
controller.move_line(vb.VISIERA_11)
controller.move_circle(vb.VISIERA_12,vb.VISIERA_13)
controller.move_line(vb.VISIERA_14)

# %%
controller.move_ptp(vb.LOOK_DOWN_POSITION)

# %%
controller.default_positioning()

# %%
# le coordinate si prndono così e sono una lista
controller.robot.tcp_coord , controller.robot.joints
# Out:
# ([33.99165344238281,
#   439.994384765625,
#   700.0120239257812,
#   179.9998321533203,
#   0.0010244877776131034,
#   -89.9996566772461],
#  [-115.16073608398438,
#   22.921091079711914,
#   -106.53172302246094,
#   -6.388503074645996,
#   -89.9994125366211,
#   244.8389129638672])

# %%
controller.disconnect()
