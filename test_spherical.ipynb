# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

import kinematics_v2 as kin
from robot_control import RobotController
import Variables as vb

from defects_id_wrapper import (take_defects_global,    # wrapper to take photos
                                duplicate_filter)       # filter to remove duplicates
from camera_scripts_v2 import  (draw_multiple_debug,    # function to draw debug info on the image
                                init_zed,               # function to initialize the ZED camera
                                WINDOW_NAME_RGB, WINDOW_NAME_MASK)

from spherical_movement import move_circle_spherical


IP_LAB = "192.168.1.3"
IP_SIM = "127.0.0.1"
controller = RobotController(ip_address=IP_SIM , default_position_j=vb.LOOK_DOWN_POSITION_J_INIZIO)
controller.disconnect()
controller.connect()

# initialize the ZED camera
#zed, runtime, image_zed, point_cloud = init_zed()
# Out:
# [18:09:47] INFO     Succesfully connected to robot Ethernet Slave and Modbus.                         techman.py:25
# [18:09:48] INFO     Connected to Listen Node                                                          techman.py:37

# %%
controller.default_positioning()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 controller.default_positioning()
#
# File c:\Users\cosid\Desktop\Industrial Robotics\Project\robot_control.py:38, in RobotController.default_positioning(self)
#      36 def default_positioning(self):
#      37     if self.default_position_j is not None:
# ---> 38         self.move_joints(self.default_position_j)
#
# File c:\Users\cosid\Desktop\Industrial Robotics\Project\robot_control.py:76, in RobotController.move_joints(self, joints, speed)
#      73 def move_joints(self, joints, speed=SPEED):
#      74     #speed = speed * PTP_SCALE
#      75     self.robot.ptp(joints, speed, data_format="JPP")
# ---> 76     self._wait_until_pose(joints, use_joints=True)
#
# File c:\Users\cosid\Desktop\Industrial Robotics\Project\robot_control.py:65, in RobotController._wait_until_pose(self, target_pose, use_joints)
#      62 if time.time() - start > self.default_timeout:
#      63     raise TimeoutError(f"Target non raggiunto. Errore: {np.round(errors, 2)}")
# ---> 65 time.sleep(0.2)
#
# KeyboardInterrupt:

# %%
controller.move_joints([-104.78617858886719,
 -1.4349422454833984,
 -94.326416015625,
 5.761336326599121,
 -90.0,
 -104.78628540039062])

# %%
controller.robot.joints

# %%
spherical_obj = [300, 0, 90]
p_obj, r_obj = kin.to_helmet_coordinates(spherical_obj, vb.HELMET_CENTER_GLOBAL)

print(p_obj)
print(r_obj)
ee_pose = kin.compute_ee_pose_for_tool_target(p_obj, r_obj, vb.CAMERA_POSE_EE)
print(ee_pose)
controller.move_ptp(ee_pose)

# %%
esph = [300, 0, 50]
if not move_circle_spherical(controller=controller,
                             radius=300,
                             end_sph_coord=esph,
                             tool_pose_ee = vb.CAMERA_POSE_EE):
    print("nope")
